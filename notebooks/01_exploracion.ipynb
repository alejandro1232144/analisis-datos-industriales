# %% [markdown]
# <a href="https://colab.research.google.com/github/alejandro1232144/analisis-datos-industriales/blob/main/notebooks/01_exploracion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ruta_csv = "analisis-dedatos-industriales/data/raw/simulated_iiot_dataset.csv"
df = pd.read_csv(ruta_csv)

# %%
df.head()
# Out:
#    temperature  vibration   pressure   humidity  rotation_speed     voltage  \
# 0    77.483571   0.639936  27.974465  30.460962     1456.825320  215.762403
# 1    74.308678   0.592463  29.566444  35.698075     1498.439826  215.465859
# 2    78.238443   0.505963  27.622740  37.931972     1500.900844  202.043568
# 3    82.615149   0.435306  29.076115  49.438438     1523.631517  216.699098
# 4    73.829233   0.569822  24.319156  42.782766     1431.657082  227.328291
#
#     current  oil_level       load  motor_temperature  gearbox_temperature  \
# 0  4.442959  73.925925  79.669747          63.827011            61.607526
# 1  4.684535  61.111595  74.963497          65.367064            63.472503
# 2  4.528970  73.573728  78.276250          62.493450            62.013095
# 3  4.726002  68.831380  87.147317          50.287512            65.552090
# 4  4.892925  73.537289  92.778567          59.222888            70.985893
#
#    sound_level    fan_speed  reactive_power  active_power  machine_failure  \
# 0    71.465461  1258.740703       50.058682     97.757590                0
# 1    76.298551  1106.050953       52.637193     97.891653                0
# 2    78.332260  1183.610247       41.944986    122.354274                0
# 3    77.265555  1197.916999       45.400509    108.093109                0
# 4    78.253433  1200.795433       49.259107    124.806509                1
#
#        timestamp
# 0  1/1/2024 0:00
# 1  1/1/2024 1:00
# 2  1/1/2024 2:00
# 3  1/1/2024 3:00
# 4  1/1/2024 4:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperature          1000 non-null   float64
#  1   vibration            1000 non-null   float64
#  2   pressure             1000 non-null   float64
#  3   humidity             1000 non-null   float64
#  4   rotation_speed       1000 non-null   float64
#  5   voltage              1000 non-null   float64
#  6   current              1000 non-null   float64
#  7   oil_level            1000 non-null   float64
#  8   load                 1000 non-null   float64
#  9   motor_temperature    1000 non-null   float64
#  10  gearbox_temperature  1000 non-null   float64
#  11  sound_level          1000 non-null   float64
#  12  fan_speed            1000 non-null   float64
#  13  reactive_power       1000 non-null   float64
#  14  active_power         1000 non-null   float64
#  15  machine_failure      1000 non-null   int64
#  16  timestamp            1000 non-null   object
# dtypes: float64(15), int64(1), object(1)
# memory usage: 132.9+ KB

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.describe()
# Out:
#        temperature    vibration     pressure     humidity  rotation_speed  \
# count  1000.000000  1000.000000  1000.000000  1000.000000     1000.000000
# mean     75.096660     0.507084    30.017503    39.906404     1497.536318
# std       4.896080     0.099745     2.950363     5.135663       49.619011
# min      58.793663     0.205961    20.941464    25.352757     1341.164809
# 25%      71.762048     0.439376    28.056001    36.312898     1465.869752
# 50%      75.126503     0.506308    29.999248    40.000923     1499.087900
# 75%      78.239719     0.572888    31.982746    43.334727     1531.956157
# max      94.263657     0.819311    41.778713    56.215465     1655.645510
#
#            voltage      current    oil_level         load  motor_temperature  \
# count  1000.000000  1000.000000  1000.000000  1000.000000        1000.000000
# mean    219.532624     4.985922    70.096085    80.183418          59.939829
# std      10.073892     0.512502     5.208700    10.116854           4.825616
# min     191.004861     3.643694    51.558174    41.633445          40.387999
# 25%     213.063072     4.622431    66.539219    73.631455          56.783329
# 50%     219.571729     4.972627    70.024899    80.191240          60.021831
# 75%     226.124468     5.349873    73.617006    86.772041          63.253711
# max     250.982994     6.764528    85.588406   113.773829          73.841868
#
#        gearbox_temperature  sound_level    fan_speed  reactive_power  \
# count          1000.000000  1000.000000  1000.000000     1000.000000
# mean             64.800457    74.966418  1200.436575       50.319840
# std               4.852018     3.044218    48.661286        5.127844
# min              48.837173    64.873263  1060.851978       34.587189
# 25%              61.565503    73.026418  1167.578101       46.849870
# 50%              64.718429    74.903191  1200.553492       50.402801
# 75%              68.061675    76.904721  1233.210037       53.686347
# max              79.570546    85.133305  1364.205910       67.144552
#
#        active_power  machine_failure
# count   1000.000000      1000.000000
# mean     100.311680         0.162000
# std       10.074989         0.368635
# min       66.704962         0.000000
# 25%       93.355223         0.000000
# 50%      100.112341         0.000000
# 75%      107.190268         0.000000
# max      131.404229         1.000000

# %%
df.isnull().sum()
# Out:
# temperature            0
# vibration              0
# pressure               0
# humidity               0
# rotation_speed         0
# voltage                0
# current                0
# oil_level              0
# load                   0
# motor_temperature      0
# gearbox_temperature    0
# sound_level            0
# fan_speed              0
# reactive_power         0
# active_power           0
# machine_failure        0
# timestamp              0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
corr = df.drop(columns=["timestamp"]).corr()

plt.imshow(corr, cmap="coolwarm")
plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Matriz de correlación")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["temperature"], bins=30)
plt.xlabel("Temperatura")
plt.ylabel("Frecuencia")
plt.title("Distribución de la temperatura")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["vibration"], bins=30)
plt.xlabel("Vibración")
plt.ylabel("Frecuencia")
plt.title("Distribución de la vibración")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["pressure"], bins=30)
plt.xlabel("Presión")
plt.ylabel("Frecuencia")
plt.title("Distribución de la presión")
plt.show()

# %% [markdown]
# # **Análisis univariado**
#
# Los histogramas muestran la distribución de las principales variables del sistema. Las variables presentan rangos de operación estables, lo que indica un comportamiento normal del sistema bajo condiciones estándar.

# %%
# Parámetros de ventaneo
fs = 1        # frecuencia de muestreo (1 muestra por unidad de tiempo)
w_sec = 20    # tamaño de ventana en segundos
w_size = fs * w_sec

w_size
# Out:
# 20

# %%
def extraer_features(signal):
    return {
        "mean": signal.mean(),
        "std": signal.std(),
        "rms": np.sqrt(np.mean(signal**2)),
        "peak": signal.max() - signal.min()
    }

# %%
features = []

for i in range(0, len(df) - w_size, w_size):
    ventana = df["vibration"].iloc[i:i+w_size]
    feats = extraer_features(ventana)
    feats["machine_failure"] = df["machine_failure"].iloc[i:i+w_size].max()
    features.append(feats)

df_features = pd.DataFrame(features)
df_features.head()
# Out:
#        mean       std       rms      peak  machine_failure
# 0  0.543383  0.083529  0.549448  0.276445                1
# 1  0.513862  0.103503  0.523671  0.381085                1
# 2  0.527660  0.085563  0.534210  0.326032                1
# 3  0.478439  0.116016  0.491620  0.434930                1
# 4  0.516744  0.078455  0.522371  0.407495                1

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   mean             49 non-null     float64
#  1   std              49 non-null     float64
#  2   rms              49 non-null     float64
#  3   peak             49 non-null     float64
#  4   machine_failure  49 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.0 KB

# %%
baseline = df_features[df_features["machine_failure"] == 0]

umbral_rms = baseline["rms"].mean() + 2 * baseline["rms"].std()
umbral_rms
# Out:
# nan

# %%
df_features["anom"] = (df_features["rms"] > umbral_rms).astype(int)

df_features.head()
# Out:
#        mean       std       rms      peak  machine_failure  anom
# 0  0.543383  0.083529  0.549448  0.276445                1     0
# 1  0.513862  0.103503  0.523671  0.381085                1     0
# 2  0.527660  0.085563  0.534210  0.326032                1     0
# 3  0.478439  0.116016  0.491620  0.434930                1     0
# 4  0.516744  0.078455  0.522371  0.407495                1     0

# %%
plt.figure(figsize=(8,4))
plt.plot(df_features["rms"], label="RMS")
plt.axhline(umbral_rms, color="red", linestyle="--", label="Umbral")
plt.xlabel("Ventana")
plt.ylabel("RMS")
plt.title("Detección de anomalías basada en RMS")
plt.legend()
plt.show()

# %%
eventos = df_features[df_features["anom"] == 1]
eventos
# Out:
# Empty DataFrame
# Columns: [mean, std, rms, peak, machine_failure, anom]
# Index: []

# %% [markdown]
# ## Detección de anomalías
#
# Se definió un umbral basado en el comportamiento normal del RMS
# (media + 2·desviación estándar). Bajo este criterio no se detectaron
# ventanas fuera de rango, lo que indica que el sistema presenta un
# funcionamiento estable durante el periodo analizado.

# %% [markdown]
# ## Conclusiones
#
# El análisis exploratorio y el ventaneo permitieron caracterizar el
# comportamiento del sistema industrial a partir de señales de vibración.
# Las features estadísticas muestran estabilidad en las variables clave.
#
# Como mejora futura, se recomienda ajustar el umbral o emplear métodos
# más avanzados de detección para identificar fallas incipientes.

# %%
df_features.head()
# Out:
#        mean       std       rms      peak  machine_failure  anom
# 0  0.543383  0.083529  0.549448  0.276445                1     0
# 1  0.513862  0.103503  0.523671  0.381085                1     0
# 2  0.527660  0.085563  0.534210  0.326032                1     0
# 3  0.478439  0.116016  0.491620  0.434930                1     0
# 4  0.516744  0.078455  0.522371  0.407495                1     0

# %%
import os

os.makedirs("data", exist_ok=True)

# %%
df_features.to_csv("data/features.csv", index=False)

# %%
import os
os.listdir("data")
# Out:
# ['features.csv']
